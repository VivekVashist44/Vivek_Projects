# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.array([2,4,5,7])
b=np.array([2,3,4,45])

plt.subplot(2,2,1)
plt.plot(a,b)

a1=np.array([1,2,3,4])
b1=np.array([10,13,14,15])

plt.subplot(2,2,2)
plt.plot(a1,b1)

m=np.array([1,2,3,4])
n=np.array([12,13,44,45])

plt.subplot(2,2,3)
plt.plot(m,n)

m1=np.array([2,12,14,27])
n1=np.array([12,13,44,45])

plt.subplot(2,2,4)
plt.plot(m1,n1)
plt.show()

# %% [markdown]
# # In the first subplot (top-left), plot a bar chart using the following data:
# Categories: ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
# Values: [23, 56, 41, 62, 19]

# %%
import numpy as np
import matplotlib.pyplot as plt

Categories= ['Category A', 'Category B', 'Category C', 'Category D', 'Category E'] 
Values= [23, 56, 41, 62, 19]

plt.subplot(2,2,1)
plt.bar(a,b)

a1=np.array([1,2,3,4])
b1=np.array([10,13,14,15])

plt.subplot(2,2,2)
plt.plot(a1,b1)

m=np.array([1,2,3,4])
n=np.array([12,13,44,45])

plt.subplot(2,2,3)
plt.plot(m,n)

m1=np.array([2,12,14,27])
n1=np.array([12,13,44,45])

plt.subplot(2,2,4)
plt.plot(m1,n1)
plt.show()

# %% [markdown]
# # In the second subplot (top-right), plot a histogram using the following data:
# Data: [12, 17, 21, 18, 14, 13, 16, 9, 12, 15, 19, 11, 14, 16, 20, 18, 15, 13, 16, 11, 10]

# %%
import numpy as np
import matplotlib.pyplot as plt

Categories= ['Category A', 'Category B', 'Category C', 'Category D', 'Category E'] 
Values= [23, 56, 41, 62, 19]

plt.subplot(2,2,1)
plt.bar(a,b)

Data= [12, 17, 21, 18, 14, 13, 16, 9, 12, 15, 19, 11, 14, 16, 20, 18, 15, 13, 16, 11, 10]

plt.subplot(2,2,2)
plt.hist(Data)

m=np.array([1,2,3,4])
n=np.array([12,13,44,45])

plt.subplot(2,2,3)
plt.plot(m,n)

m1=np.array([2,12,14,27])
n1=np.array([12,13,44,45])

plt.subplot(2,2,4)
plt.plot(m1,n1)
plt.show()

# %% [markdown]
# # In the third subplot (bottom-left), plot a pie chart using the following data:
# Labels: ['Apple', 'Banana', 'Orange', 'Mango']
# Sizes: [30, 25, 15, 30]

# %%
import numpy as np
import matplotlib.pyplot as plt

Categories= ['Category A', 'Category B', 'Category C', 'Category D', 'Category E'] 
Values= [23, 56, 41, 62, 19]

plt.subplot(2,2,1)
plt.bar(a,b)

Data= [12, 17, 21, 18, 14, 13, 16, 9, 12, 15, 19, 11, 14, 16, 20, 18, 15, 13, 16, 11, 10]

plt.subplot(2,2,2)
plt.hist(Data)

Labels= ['Apple', 'Banana', 'Orange', 'Mango']
Sizes =  [30, 25, 15, 30]    

plt.subplot(2,2,3)
plt.pie(Sizes,labels=Labels)

m1=np.array([2,12,14,27])
n1=np.array([12,13,44,45])

plt.subplot(2,2,4)
plt.plot(m1,n1)
plt.show()

# %% [markdown]
# # In the fourth subplot (bottom-right), plot a scatter plot using the following data:
# X values: [1, 2, 3, 4, 5]
# Y values: [2, 5, 3, 6, 4]

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

Categories= ['Category A', 'Category B', 'Category C', 'Category D', 'Category E'] 
Values= [23, 56, 41, 62, 19]

plt.subplot(2,2,1)
plt.bar(Categories,Values)

Data= [12, 17, 21, 18, 14, 13, 16, 9, 12, 15, 19, 11, 14, 16, 20, 18, 15, 13, 16, 11, 10]

plt.subplot(2,2,2)
plt.hist(Data)

Labels= ['Apple', 'Banana', 'Orange', 'Mango']
Sizes =  [30, 25, 15, 30]    

plt.subplot(2,2,3)
plt.pie(Sizes,labels=Labels)

X_values= [1, 2, 3, 4, 5]
Y_values= [2, 5, 3, 6, 4]

plt.subplot(2,2,4)
plt.scatter(X_values,Y_values)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

Categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
Values = [23, 56, 41, 62, 19]

plt.subplot(2, 2, 1)
plt.bar(Categories, Values)
plt.title('Bar Plot')
plt.xlabel('Categories')
plt.ylabel('Values')

Data = [12, 17, 21, 18, 14, 13, 16, 9, 12, 15, 19, 11, 14, 16, 20, 18, 15, 13, 16, 11, 10]

plt.subplot(2, 2, 2)
plt.hist(Data)
plt.title('Histogram')
plt.xlabel('Data')
plt.ylabel('Frequency')

Labels = ['Apple', 'Banana', 'Orange', 'Mango']
Sizes = [30, 25, 15, 30]

plt.subplot(2, 2, 3)
plt.pie(Sizes, labels=Labels)
plt.title('Pie Chart')

X_values = [1, 2, 3, 4, 5]
Y_values = [2, 5, 3, 6, 4]

plt.subplot(2, 2, 4)
plt.scatter(X_values, Y_values)
plt.title('Scatter Plot')
plt.xlabel('X values')
plt.ylabel('Y values')

plt.tight_layout() 

plt.show()
